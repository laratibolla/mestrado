# %%
# %matplotlib inline
import os
import numpy as np
import math
import matplotlib.pyplot as plt 
import pandas as pd
from random import random
from scipy import special
amostra=[]
x=[]
n=100000
mu=0.5
gamma=0.2
for i in range(1,n):
    r=random()
    y=mu+gamma*math.tan(math.pi*(r-0.5))
    x.append(i)
    amostra.append(y)
# plt.plot(x,amostra,'-o')
dados={'y':amostra}
bins=np.arange(-1,3,.01)
df=pd.DataFrame(data=dados).hist(bins=bins)
# df=df.sort_values(by='y',ascending=True).plot(kind='bar')
